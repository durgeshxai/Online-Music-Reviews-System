# %%
import google.generativeai as genai
import requests

#Gemini API Key
genai.configure(api_key="AIzaSyCPws6K2pxDxa2-dfkas2KoEs3_tkTkmVk")

# Load Gemini 1.5 Pro Model
model = genai.GenerativeModel("gemini-2.0-pro")

# Simulate fetching dynamic review 
def get_music_review(artist_name):
    # In real setup: scrape or call API
    simulated_reviews = {
        "Adele": "Adele's voice shines with emotional depth, and her lyrics are personal and relatable.",
        "Eminem": "Lyrically intense and emotionally charged, Eminem delivers raw storytelling with his iconic style.",
        "The Weeknd": "Synth-heavy, dark pop soundscapes with emotionally complex lyrics about love and fame."
    }
    return simulated_reviews.get(artist_name, f"{artist_name} is a talented artist with a unique style. Review data not found, so this is a placeholder.")

# Analyze review using Gemini
def analyze_review(artist_name, review_text):
    prompt = f"""
    Artist: {artist_name}
    Review: "{review_text}"

    1. Summarize this review.
    2. What's the sentiment (positive, neutral, negative)?
    3. Recommend 2-3 similar artists based on the style.
    """
    response = model.generate_content(prompt)
    return response.text

# Chatbot loop
def run_chatbot():
    print("Welcome to the Music Reviews Chatbot (Gemini 1.5 Powered)")
    while True:
        artist = input("\nEnter artist/album name (or type 'exit'): ")
        if artist.lower() == "exit":
            break

        review = get_music_review(artist)
        print("\nFetching and analyzing review...\n")
        reply = analyze_review(artist, review)
        print("Gemini's Review Analysis:\n", reply)

run_chatbot()
# Out:
# Welcome to the Music Reviews Chatbot (Gemini 1.5 Powered)
